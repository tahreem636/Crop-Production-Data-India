# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/Crop-Production-Data-India/blob/main/crop%20pruduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/CONTENT/'

# %%
# !kaggle datasets download -d iamtapendu/crop-production-data-india
# Out:
# Dataset URL: https://www.kaggle.com/datasets/iamtapendu/crop-production-data-india
# License(s): apache-2.0
# ...
#   0% 0.00/1.95M [00:00<?, ?B/s]
# 100% 1.95M/1.95M [00:00<00:00, 126MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/crop-production-data-india.zip')
df
# Out:
#                  State_Name    District_Name  Crop_Year       Season  \
# 0       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 1       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 2       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 3       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
# 4       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
# ...                     ...              ...        ...          ...
# 246086          West Bengal         PURULIYA       2014  Summer
# 246087          West Bengal         PURULIYA       2014  Summer
# 246088          West Bengal         PURULIYA       2014  Whole Year
# 246089          West Bengal         PURULIYA       2014  Winter
# 246090          West Bengal         PURULIYA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# ...
